# %% [markdown]
# # Linear Regression : 설명을 위한 선형회귀분석
#
#  1) 종속변수 y : 만성폐쇄성폐질환 (COPD) 삶의 질 평가 검사(CAT) 증상점수
#  *  COPD 평가검사(COPD assessment test, CAT)
#  * CAT는 8가지 설문 사항을 통해 환자의 삶의 질 즉, 호흡기 증상, 활동 정도, 수면, 자신감을 지표로 삼고 평가
#  * 0(삶의 질 가장 좋음)~40점(삶의 질 가장 나쁨)까지의 점수로 나타남
#
# 2) 독립변수 x (7개)
#  * age :나이, 연속형
#  * sex :성별(1:남성, 0:여성), 범주형
#  * FEV1%: 1초간 노력성 폐활량(Forced Expiratory Volume in One second, FEV1), 연속형,
#   - (> 70 :mild, 60-69 :moderate ,50-59:moderagely severe, 35-49:severe, <35 :very severe)
#  * Smoke_pack_year : 갑년(pack-year), 사람의 담배 노출을 측정하는 데 사용되는 지표, 하루평균 담배소비량(갑)×흡연기간(년)을 의미
#  * Chol :  혈중 콜레스트롤 (mg / dl 단위), 연속형
#  * Comorbid : 동반질환여부 (1:유, 0:무), 범주형
#  * premium : 월평균 건강보험료(소득수준 의미), 연속형
#
#  * COPD 환자의 80% 이상에서 10갑년 이상의 흡연력. 을 가지며, 특히 남자에서는 90% 이상 흡연과 관련

# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd
import numpy as np
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %%
df=pd.read_csv('copdcat.csv')

# %%
df.describe()
# Out:
#                age          sex        FEV1%  Smoke_pack_year         Chol  \
# count  5251.000000  5251.000000  5251.000000      5251.000000  5251.000000
# mean     49.558560     0.491525    52.491173        21.499791   203.663826
# std       7.961511     0.499976    15.835327        17.278496    35.946611
# min      24.000000     0.000000    25.010000         0.000000   150.030000
# 25%      44.000000     0.000000    38.985000         6.200000   175.285000
# 50%      50.000000     0.000000    52.610000        19.800000   198.550000
# 75%      55.000000     1.000000    65.915000        33.300000   224.690000
# max      81.000000     1.000000    79.990000        86.400000   397.390000
#
#           Comorbid        premium     CATScore
# count  5251.000000    5251.000000  5251.000000
# mean      0.509617   55105.500857     9.512321
# std       0.499955   14884.283602     3.506540
# min       0.000000    2172.000000     1.000000
# 25%       0.000000   45031.000000     7.200000
# 50%       1.000000   55134.000000     9.000000
# 75%       1.000000   65237.500000    11.200000
# max       1.000000  115233.000000    40.000000

# %%
X=df.drop(["CATScore"],axis=1)
y=df["CATScore"]

# %% [markdown]
# ### 그래프를 활용한 탐색적 분석

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df, x_vars=X.columns, y_vars='CATScore', kind='reg', 
             plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.01}})
plt.show()

# %% [markdown]
# ###  Model1 :기본 모델구축
# * Adj. R-squared : 0.74
# * 유의수준 5% 하에서 유의하지 않은 변수 : Chol
# * FEV1%(폐활량 테스트 점수)가 높을 수록, 연평균 보험료가 높을 수록 만성폐쇄성폐질환자의 삶의 질 증상점수가 낮아짐(삶의 질이 좋아짐)
# * 나이가 많을 수록, 성별이 여성대비 남성인 경우, 과거 흡연력이 클수록, 동반질환이 있을 수록 COPD환자의 증상 점수는 높아짐

# %%
import statsmodels.api as sm
model_reg = sm.OLS(y,sm.add_constant(X)) # <---- 선형회귀분석
result_reg = model_reg.fit()
result_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               CATScore   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     2130.
# Date:                Wed, 10 Nov 2021   Prob (F-statistic):               0.00
# Time:                        09:22:58   Log-Likelihood:                -10503.
# No. Observations:                5251   AIC:                         2.102e+04
# Df Residuals:                    5243   BIC:                         2.107e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               9.7637      0.246     39.756      0.000       9.282      10.245
# age                 0.0147      0.003      4.733      0.000       0.009       0.021
# sex                 0.2690      0.049      5.446      0.000       0.172       0.366
# FEV1%              -0.0787      0.002    -50.431      0.000      -0.082      -0.076
# Smoke_pack_year     0.1542      0.001    107.823      0.000       0.151       0.157
# Chol                0.0003      0.001      0.387      0.699      -0.001       0.002
# Comorbid            0.9392      0.049     19.006      0.000       0.842       1.036
# premium         -1.504e-05   1.66e-06     -9.058      0.000   -1.83e-05   -1.18e-05
# ==============================================================================
# Omnibus:                     1902.692   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20452.640
# Skew:                           1.418   Prob(JB):                         0.00
# Kurtosis:                      12.243   Cond. No.                     5.68e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.68e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Linearity
# > 가정사항 위반 확인법 수행

# %%
sns.scatterplot(x=df['CATScore'], y=result_reg.fittedvalues, alpha=0.1)
plt.plot([0, 30], [0, 30], color='red')
plt.ylabel("Fitted values")
plt.show()

# %%
# linearity
sns.scatterplot(x=result_reg.fittedvalues, y=result_reg.resid, alpha=0.1)
plt.axhline(y=0, color='red')
plt.xlabel("Fitted values")
plt.ylabel("Residual")
plt.show()

# %% [markdown]
# #### Normality

# %%
sm.qqplot(result_reg.resid, line='r')
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# #### Equal Variance

# %%
sns.scatterplot(x=result_reg.fittedvalues, y=result_reg.resid, alpha=0.1)
plt.axhline(y=0, color='red')
plt.xlabel("Fitted values")
plt.ylabel("Residual")
plt.show()

# %% [markdown]
# ### 모형 고급화 방안

# %%
# More on linearity
df1=df.join(pd.DataFrame({'residual': result_reg.resid}))
sns.pairplot(df1, x_vars=X.columns, y_vars='residual', kind='reg', 
             plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.01}})

# %% [markdown]
# ### Molde2 : X 변수 변환 추가

# %%
X=df.drop(["CATScore"],axis=1)
y=df["CATScore"]
X["Smoke_pack_year2"]= df["Smoke_pack_year"]**2
model_reg2 = sm.OLS(y,sm.add_constant(X))
result_reg2 = model_reg2.fit()
result_reg2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               CATScore   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     2998.
# Date:                Wed, 10 Nov 2021   Prob (F-statistic):               0.00
# Time:                        09:23:00   Log-Likelihood:                -9526.7
# No. Observations:                5251   AIC:                         1.907e+04
# Df Residuals:                    5242   BIC:                         1.913e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               10.8857      0.205     53.038      0.000      10.483      11.288
# age                  0.0135      0.003      5.247      0.000       0.008       0.019
# sex                  0.2566      0.041      6.254      0.000       0.176       0.337
# FEV1%               -0.0784      0.001    -60.516      0.000      -0.081      -0.076
# Smoke_pack_year      0.0031      0.003      0.945      0.344      -0.003       0.010
# Chol                 0.0004      0.001      0.684      0.494      -0.001       0.002
# Comorbid             1.0085      0.041     24.560      0.000       0.928       1.089
# premium          -1.603e-05   1.38e-06    -11.619      0.000   -1.87e-05   -1.33e-05
# Smoke_pack_year2     0.0029   5.87e-05     48.592      0.000       0.003       0.003
# ==============================================================================
# Omnibus:                      812.043   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3307.828
# Skew:                           0.716   Prob(JB):                         0.00
# Kurtosis:                       6.615   Cond. No.                     5.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Linearity

# %%
sns.scatterplot(x=df['CATScore'], y=result_reg2.fittedvalues, alpha=0.1)
plt.plot([0, 30], [0, 30], color='red')
plt.ylabel("Fitted values")
plt.show()

# %% [markdown]
# #### Normality

# %%
sm.qqplot(result_reg2.resid, line='r')
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# #### Equal variance

# %%
sns.scatterplot(x=result_reg2.fittedvalues, y=result_reg2.resid, alpha=0.1)
plt.axhline(y=0, color='red')
plt.xlabel("Fitted values")
plt.ylabel("Residual")
plt.show()

# %% [markdown]
# ## 다중공선성 확인
# ### correlation

# %%
plt.figure(figsize=(10,5))
sns.heatmap(X.corr(),cmap='coolwarm',annot=True)
plt.show()

# %% [markdown]
# ### VIF 계산

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_design = sm.add_constant(X)
vif = pd.DataFrame()
vif["Features"] = X.columns
vif["VIF Factor"] = [np.round(variance_inflation_factor(X_design.values, i+1),4) 
                     for i in range(len(X.columns))] 
vif
# Out:
#            Features  VIF Factor
# 0               age      1.0005
# 1               sex      1.0001
# 2             FEV1%      1.0012
# 3   Smoke_pack_year      7.8633
# 4              Chol      1.0003
# 5          Comorbid      1.0017
# 6           premium      1.0019
# 7  Smoke_pack_year2      7.8648

# %% [markdown]
# ## 이상점, 영향점

# %%
result_influ = result_reg2.get_influence().summary_frame() #slow
result_influ
# Out:
#       dfb_const   dfb_age   dfb_sex  dfb_FEV1%  dfb_Smoke_pack_year  dfb_Chol  \
# 0     -0.003946  0.005481  0.012877   0.017002            -0.002433 -0.011759
# 1      0.025115 -0.004162  0.020395   0.001035            -0.029061 -0.019484
# 2     -0.004637  0.007410  0.010879   0.012208             0.005503 -0.002870
# 3     -0.034944  0.032776 -0.020481   0.023207             0.009251  0.006607
# 4     -0.004632 -0.002940  0.017654   0.026354             0.016792 -0.009074
# ...         ...       ...       ...        ...                  ...       ...
# 5246  -0.001293  0.004569 -0.007851  -0.000239             0.011633 -0.008308
# 5247   0.074362 -0.066977 -0.042780   0.015055             0.019983 -0.024195
# 5248   0.001660 -0.003161  0.003838   0.000518            -0.002706  0.000596
# 5249   0.007127 -0.002692 -0.006369  -0.004411            -0.002602 -0.000544
# 5250  -0.004909  0.007448 -0.008056  -0.005994            -0.000917  0.000652
#
#       dfb_Comorbid  dfb_premium  dfb_Smoke_pack_year2   cooks_d  \
# 0         0.012145     0.003528             -0.000619  0.000115
# 1        -0.020454    -0.011357              0.021186  0.000321
# 2        -0.011339    -0.004369             -0.007102  0.000071
# 3         0.020773     0.004268              0.001300  0.000418
# 4         0.016320    -0.004701             -0.013406  0.000225
# ...            ...          ...                   ...       ...
# 5246     -0.007656     0.005029             -0.008778  0.000051
# 5247     -0.044053    -0.048199             -0.000290  0.001846
# 5248      0.004074    -0.003047              0.003141  0.000009
# 5249     -0.006292    -0.005381             -0.000637  0.000028
# 5250      0.008305     0.002119              0.002695  0.000035
#
#       standard_resid  hat_diag  dffits_internal  student_resid    dffits
# 0           0.919556  0.001218         0.032113       0.919543  0.032113
# 1           1.466113  0.001343         0.053772       1.466273  0.053778
# 2           0.770916  0.001073         0.025264       0.770886  0.025263
# 3           1.505264  0.001656         0.061300       1.505446  0.061307
# 4           1.255094  0.001281         0.044951       1.255163  0.044953
# ...              ...       ...              ...            ...       ...
# 5246       -0.562562  0.001454        -0.021470      -0.562526 -0.021468
# 5247        3.140353  0.001682         0.128888       3.143011  0.128997
# 5248       -0.285523  0.000939        -0.008755      -0.285498 -0.008754
# 5249       -0.452898  0.001222        -0.015842      -0.452864 -0.015841
# 5250       -0.569874  0.000971        -0.017765      -0.569837 -0.017763
#
# [5251 rows x 15 columns]

# %% [markdown]
# #### Studentized Residual, Leverage Hii

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=result_influ, y="student_resid", x="hat_diag", alpha=0.5)
plt.show()

# %% [markdown]
# #### Cook's distnace, Dffits

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=result_influ, y="dffits", x="cooks_d", alpha=0.5)
plt.show()

# %% [markdown]
# #### 영향점 상위 10개

# %%
result_influ_sort = result_influ.sort_values('cooks_d', ascending=False)
result_influ_sort[['cooks_d','student_resid','dffits','hat_diag']].head(10)
# Out:
#        cooks_d  student_resid    dffits  hat_diag
# 3110  0.140447       8.983825  1.132804  0.015651
# 3405  0.052760       6.903423  0.692149  0.009952
# 4311  0.031471       5.851284  0.533883  0.008256
# 2184  0.024002       4.999602  0.465841  0.008607
# 4032  0.022835       6.186947  0.454947  0.005378
# 1063  0.021957       5.328851  0.445696  0.006947
# 3489  0.021219       6.066202  0.438492  0.005198
# 4947  0.021114       5.900786  0.437321  0.005463
# 4197  0.021101       5.376268  0.436942  0.006562
# 2252  0.018922       6.011005  0.414050  0.004722

# %% [markdown]
# ####  [해석을 위한 참고] Model2 : 이차항을 포함한 회귀분석
# * 선형 회귀 모형의 actual CAT Score 와 predicted CAT Score 그림을 보았을 때, curve의 형태를 보이는 선형으로는 설명 불가능한 부분이 보임
# * 탐색적 그래프 분석에서 Smoke_pack_year 변수가 이차항 효과를 가지는 것으로 보여져, 해당 변수의 이차항을 추가
# * 후진제거법으로 Chol 과 Smoke_pack_year 변수는 삭제함
# * 폐 기능 검사의 노력성 폐활량 FEV1% 점수가 나쁠수록, 흡연력이 길수록, 동반질환이 있을 수록, 연 평균 보험료(소득수준)이 적을수록,
# 여성보다는 남성이, 나이가 많을 수록  삶의 질 검사(CAT) 증상 점수가 높은 점수를 보인다 (증상 악화, 삶의 질이 나쁨을 뜻함)
