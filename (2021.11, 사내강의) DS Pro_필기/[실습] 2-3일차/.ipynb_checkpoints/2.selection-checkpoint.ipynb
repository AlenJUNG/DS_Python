# %% [markdown]
# # 지도학습 feature selection
# ## 분류 분석 데이터 (불량/정상 제품)
# ### 다중 t-검정 기반 feature selection

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

# %%
df = pd.read_csv('product.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 72 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Defect  893 non-null    object
#  1   Para01  893 non-null    float64
#  2   Para02  893 non-null    float64
#  3   Para03  893 non-null    float64
#  4   Para04  893 non-null    float64
#  5   Para05  893 non-null    float64
#  6   Para06  893 non-null    float64
#  7   Para07  893 non-null    float64
#  8   Para08  893 non-null    float64
#  9   Para09  893 non-null    float64
#  10  Para10  893 non-null    float64
#  11  Para11  893 non-null    float64
#  12  Para12  893 non-null    float64
#  13  Para13  893 non-null    float64
#  14  Para14  893 non-null    float64
#  15  Para15  893 non-null    float64
#  16  Para16  893 non-null    float64
#  17  Para17  893 non-null    float64
#  18  Para18  893 non-null    float64
#  19  Para19  893 non-null    float64
#  20  Para20  893 non-null    float64
#  21  Para21  893 non-null    float64
#  22  Para22  893 non-null    float64
#  23  Para23  893 non-null    float64
#  24  Para24  893 non-null    float64
#  25  Para25  893 non-null    float64
#  26  Para26  893 non-null    float64
#  27  Para27  893 non-null    float64
#  28  Para28  893 non-null    float64
#  29  Para29  893 non-null    float64
#  30  Para30  893 non-null    float64
#  31  Para31  893 non-null    float64
#  32  Para32  893 non-null    float64
#  33  Para33  893 non-null    float64
#  34  Para34  893 non-null    float64
#  35  Para35  893 non-null    float64
#  36  Para36  893 non-null    float64
#  37  Para37  893 non-null    float64
#  38  Para38  893 non-null    float64
#  39  Para39  893 non-null    float64
#  40  Para40  893 non-null    float64
#  41  Para41  893 non-null    float64
#  42  Para42  893 non-null    float64
#  43  Para43  893 non-null    float64
#  44  Para44  893 non-null    float64
#  45  Para45  893 non-null    float64
#  46  Para46  893 non-null    float64
#  47  Para47  893 non-null    float64
#  48  Para48  893 non-null    float64
#  49  Para49  893 non-null    float64
#  50  Para50  893 non-null    float64
#  51  Para51  893 non-null    float64
#  52  Para52  893 non-null    float64
#  53  Para53  893 non-null    float64
#  54  Para54  893 non-null    float64
#  55  Para55  893 non-null    float64
#  56  Para56  893 non-null    float64
#  57  Para57  893 non-null    float64
#  58  Para58  893 non-null    float64
#  59  Para59  893 non-null    float64
#  60  Para60  893 non-null    float64
#  61  Para61  893 non-null    float64
#  62  Para62  893 non-null    float64
#  63  Para63  893 non-null    float64
#  64  Para64  893 non-null    float64
#  65  Para65  893 non-null    float64
#  66  Para66  893 non-null    float64
#  67  Para67  893 non-null    float64
#  68  Para68  893 non-null    float64
#  69  Para69  893 non-null    float64
#  70  Para70  893 non-null    float64
#  71  Para71  893 non-null    float64
# dtypes: float64(71), object(1)
# memory usage: 502.4+ KB

# %%
print(df.shape) # 데이터의 사이즈
print(df.isnull().sum().sum()) # missing value sum을 한번 하면 72개의 변수별로 계산, sum 2번이면 전체 계산
# Out:
# (893, 72)
# 0

# %%
X = df.drop('Defect', axis=1)
y = df['Defect']
y = np.where(y=="NG", 1, 0) # 공정 결과를 숫자로 변경, not good = 1, good = 0
xvar = X.columns
xvar
# Out:
# Index(['Para01', 'Para02', 'Para03', 'Para04', 'Para05', 'Para06', 'Para07',
#        'Para08', 'Para09', 'Para10', 'Para11', 'Para12', 'Para13', 'Para14',
#        'Para15', 'Para16', 'Para17', 'Para18', 'Para19', 'Para20', 'Para21',
#        'Para22', 'Para23', 'Para24', 'Para25', 'Para26', 'Para27', 'Para28',
#        'Para29', 'Para30', 'Para31', 'Para32', 'Para33', 'Para34', 'Para35',
#        'Para36', 'Para37', 'Para38', 'Para39', 'Para40', 'Para41', 'Para42',
#        'Para43', 'Para44', 'Para45', 'Para46', 'Para47', 'Para48', 'Para49',
#        'Para50', 'Para51', 'Para52', 'Para53', 'Para54', 'Para55', 'Para56',
#        'Para57', 'Para58', 'Para59', 'Para60', 'Para61', 'Para62', 'Para63',
#        'Para64', 'Para65', 'Para66', 'Para67', 'Para68', 'Para69', 'Para70',
#        'Para71'],
#       dtype='object')

# %%
# t test를 하기 위해 데이터를 둘로 쪼갬
X1 = X[y==0] # 정상
X2 = X[y==1] # 불량

# %%
var_select=[]
for i in range(0,71):
    f, p = f_oneway(X1[xvar[i]], X2[xvar[i]]) # <----- f_oneway 함수로 t test 수행, 사실 One way ANOVA
    var_select.append((xvar[i], p)) # t test는 one way ANOVA에 속함, var_select는 p value를 계속 저장함

var_select = pd.DataFrame(var_select, columns=['Para', 'P-value'])
var_select['Result0.05'] = var_select['P-value']<0.05
var_select['Result0.01'] = var_select['P-value']<0.01

# %%
np.round(var_select[var_select['Result0.05']==True],4) # p pave가 0.05로 작은 것으로 필터링하고 반올림, 소수점 이하 4째자리까지만 출력
# Out:
#       Para  P-value  Result0.05  Result0.01
# 0   Para01   0.0181        True       False
# 5   Para06   0.0000        True        True
# 8   Para09   0.0000        True        True
# 11  Para12   0.0000        True        True
# 14  Para15   0.0000        True        True
# 17  Para18   0.0000        True        True
# 23  Para24   0.0000        True        True
# 26  Para27   0.0000        True        True
# 31  Para32   0.0253        True       False
# 32  Para33   0.0004        True        True
# 36  Para37   0.0458        True       False
# 38  Para39   0.0000        True        True
# 41  Para42   0.0081        True        True
# 44  Para45   0.0000        True        True
# 50  Para51   0.0000        True        True
# 56  Para57   0.0032        True        True
# 59  Para60   0.0000        True        True
# 62  Para63   0.0000        True        True
# 65  Para66   0.0000        True        True
# 68  Para69   0.0000        True        True
# 70  Para71   0.0000        True        True

# %%
var_select[['Result0.05','Result0.01']].sum()
# Out:
# Result0.05    21
# Result0.01    18
# dtype: int64

# %% [markdown]
# ### Wrapper 방법을 이용한 feature selection

# %%
import feature_selection as fsel # 패키지가 없어서 누군가 코드를 개발해 놓은 것이 있음 (파이썬 코드를 짜놓았음, 폴더에 넣어져 있음)

# %% [markdown]
# #### 후진제거법

# %%
# elimination_criteria 기준
result_back = fsel.backwardSelection(X, y, model_type ="logistic", elimination_criteria = "aic")
# Out:
# Character Variables (Dummies Generated, First Dummies Dropped): []
# Optimization terminated successfully.
#          Current function value: 0.076216
#          Iterations 22
# Eliminated : Para05
# Optimization terminated successfully.
#          Current function value: 0.076216
#          Iterations 22
# Eliminated : Para42
# Optimization terminated successfully.
#          Current function value: 0.076217
#          Iterations 22
# Eliminated : Para45
# Optimization terminated successfully.
#          Current function value: 0.076221
#          Iterations 22
# Eliminated : Para18
# Optimization terminated successfully.
#          Current function value: 0.076227
#          Iterations 21
# Eliminated : Para31
# Optimization terminated successfully.
#          Current function value: 0.076248
#          Iterations 21
# Eliminated : Para69
# Optimization terminated successfully.
#          Current function value: 0.076276
#          Iterations 20
# Eliminated : Para40
# Optimization terminated successfully.
#          Current function value: 0.076313
#          Iterations 20
# Eliminated : Para06
# Optimization terminated successfully.
#          Current function value: 0.076354
#          Iterations 21
# Eliminated : Para35
# Optimization terminated successfully.
#          Current function value: 0.076390
#          Iterations 20
# Eliminated : Para50
# Optimization terminated successfully.
#          Current function value: 0.076442
#          Iterations 19
# Eliminated : Para30
# Optimization terminated successfully.
#          Current function value: 0.076515
#          Iterations 21
# Eliminated : Para57
# Optimization terminated successfully.
#          Current function value: 0.076583
#          Iterations 20
# Eliminated : Para17
# Optimization terminated successfully.
#          Current function value: 0.076681
#          Iterations 19
# Eliminated : Para53
# Optimization terminated successfully.
#          Current function value: 0.076770
#          Iterations 20
# Eliminated : Para55
# Optimization terminated successfully.
#          Current function value: 0.076871
#          Iterations 20
# Eliminated : Para08
# Optimization terminated successfully.
#          Current function value: 0.076953
#          Iterations 19
# Eliminated : Para71
# Optimization terminated successfully.
#          Current function value: 0.077051
#          Iterations 20
# Eliminated : Para20
# Optimization terminated successfully.
#          Current function value: 0.077181
#          Iterations 21
# Eliminated : Para52
# Optimization terminated successfully.
#          Current function value: 0.077336
#          Iterations 21
# Eliminated : Para63
# Optimization terminated successfully.
#          Current function value: 0.077559
#          Iterations 21
# Eliminated : Para28
# Optimization terminated successfully.
#          Current function value: 0.077763
#          Iterations 21
# Eliminated : Para02
# Optimization terminated successfully.
#          Current function value: 0.077988
#          Iterations 21
# Eliminated : Para11
# Optimization terminated successfully.
#          Current function value: 0.078394
#          Iterations 21
# Eliminated : Para13
# Optimization terminated successfully.
#          Current function value: 0.078767
#          Iterations 21
# Eliminated : Para16
# Optimization terminated successfully.
#          Current function value: 0.079129
#          Iterations 21
# Eliminated : Para54
# Optimization terminated successfully.
#          Current function value: 0.079422
#          Iterations 21
# Eliminated : Para58
# Optimization terminated successfully.
#          Current function value: 0.079786
#          Iterations 21
# Eliminated : Para10
# Optimization terminated successfully.
#          Current function value: 0.080144
#          Iterations 21
# Eliminated : Para70
# Optimization terminated successfully.
#          Current function value: 0.080493
#          Iterations 21
# Eliminated : Para03
# Optimization terminated successfully.
#          Current function value: 0.080686
#          Iterations 21
# Eliminated : Para43
# Optimization terminated successfully.
#          Current function value: 0.081264
#          Iterations 20
# Eliminated : Para68
# Optimization terminated successfully.
#          Current function value: 0.081741
#          Iterations 20
# Eliminated : Para46
# Optimization terminated successfully.
#          Current function value: 0.082189
#          Iterations 20
# Eliminated : Para51
# Optimization terminated successfully.
#          Current function value: 0.082679
#          Iterations 20
# Eliminated : Para39
# Optimization terminated successfully.
#          Current function value: 0.083012
#          Iterations 20
# Eliminated : Para49
# Optimization terminated successfully.
#          Current function value: 0.083661
#          Iterations 20
# Eliminated : Para34
# Optimization terminated successfully.
#          Current function value: 0.084258
#          Iterations 20
# Eliminated : Para19
# Optimization terminated successfully.
#          Current function value: 0.084943
#          Iterations 20
# Eliminated : Para56
# Optimization terminated successfully.
#          Current function value: 0.085641
#          Iterations 20
# Eliminated : Para38
# Optimization terminated successfully.
#          Current function value: 0.086215
#          Iterations 20
# Eliminated : Para25
# Optimization terminated successfully.
#          Current function value: 0.087093
#          Iterations 20
# Eliminated : Para12
# Optimization terminated successfully.
#          Current function value: 0.087729
#          Iterations 20
# Eliminated : Para60
# Optimization terminated successfully.
#          Current function value: 0.088330
#          Iterations 20
# Eliminated : Para29
# Optimization terminated successfully.
#          Current function value: 0.089243
#          Iterations 19
# Eliminated : Para09
# Optimization terminated successfully.
#          Current function value: 0.090255
#          Iterations 19
# Eliminated : Para22
# Optimization terminated successfully.
#          Current function value: 0.091348
#          Iterations 18
# Eliminated : Para41
# Optimization terminated successfully.
#          Current function value: 0.092379
#          Iterations 18
# Eliminated : Para64
# Optimization terminated successfully.
#          Current function value: 0.093458
#          Iterations 18
# Eliminated : Para14
# Optimization terminated successfully.
#          Current function value: 0.094722
#          Iterations 18
# Regained :  Para14
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  893
# Model:                          Logit   Df Residuals:                      869
# Method:                           MLE   Df Model:                           23
# Date:                Tue, 09 Nov 2021   Pseudo R-squ.:                  0.4468
# Time:                        11:45:46   Log-Likelihood:                -83.458
# converged:                       True   LL-Null:                       -150.86
# Covariance Type:            nonrobust   LLR p-value:                 8.402e-18
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -1218.6914    357.942     -3.405      0.001   -1920.245    -517.138
# Para01         0.0670      0.040      1.660      0.097      -0.012       0.146
# Para04         0.0992      0.043      2.315      0.021       0.015       0.183
# Para07        -0.0880      0.041     -2.149      0.032      -0.168      -0.008
# Para14         0.0175      0.012      1.489      0.136      -0.006       0.041
# Para15       -13.8909      9.156     -1.517      0.129     -31.836       4.055
# Para21      1801.7408    957.560      1.882      0.060     -75.043    3678.524
# Para23         0.0227      0.011      1.990      0.047       0.000       0.045
# Para24        -0.0043      0.001     -3.384      0.001      -0.007      -0.002
# Para26         0.0301      0.011      2.619      0.009       0.008       0.053
# Para27        -0.0137      0.006     -2.124      0.034      -0.026      -0.001
# Para32         0.0234      0.011      2.085      0.037       0.001       0.045
# Para33       102.3150     35.403      2.890      0.004      32.927     171.704
# Para36       -31.7935     16.640     -1.911      0.056     -64.408       0.821
# Para37         0.0931      0.039      2.416      0.016       0.018       0.169
# Para44        -0.0215      0.011     -1.981      0.048      -0.043      -0.000
# Para47         0.0223      0.011      2.040      0.041       0.001       0.044
# Para48         9.2417      6.114      1.511      0.131      -2.742      21.226
# Para59        -0.0246      0.012     -2.084      0.037      -0.048      -0.001
# Para61         0.0912      0.040      2.289      0.022       0.013       0.169
# Para62        -0.0230      0.011     -2.086      0.037      -0.045      -0.001
# Para65         0.0274      0.011      2.523      0.012       0.006       0.049
# Para66        40.9526     12.137      3.374      0.001      17.165      64.741
# Para67        -0.0599      0.040     -1.497      0.134      -0.138       0.019
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.54 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# AIC: 214.91593755376874
# BIC: 329.98601549480475
# Final Variables: ['intercept', 'Para01', 'Para04', 'Para07', 'Para14', 'Para15', 'Para21', 'Para23', 'Para24', 'Para26', 'Para27', 'Para32', 'Para33', 'Para36', 'Para37', 'Para44', 'Para47', 'Para48', 'Para59', 'Para61', 'Para62', 'Para65', 'Para66', 'Para67']

# %% [markdown]
# #### 전진제거법

# %%
result_forward = fsel.forwardSelection(X, y, model_type ="logistic", elimination_criteria = "aic")
# Out:
# Character Variables (Dummies Generated, First Dummies Dropped): []
# Optimization terminated successfully.
#          Current function value: 0.168939
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.165699
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168745
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168938
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168815
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168922
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.147576
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.167590
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168791
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.143020
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.168900
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168822
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.147690
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.168930
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.167484
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.146525
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.168926
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168936
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.146887
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.168799
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168907
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168357
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.168793
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168053
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.134097
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.168714
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168128
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.148400
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168632
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168258
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.167687
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168615
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.166109
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162221
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168915
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168750
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168787
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.166692
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168704
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.148247
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168722
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168484
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.165464
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168579
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168637
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.143086
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.168796
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168020
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168844
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168819
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168577
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.153958
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.167703
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168832
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.167963
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168856
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168591
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.164414
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168686
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.167778
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.144177
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.168296
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168350
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.137291
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.167598
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168150
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.134215
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.168836
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.168930
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.140188
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.168294
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.138038
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.134097
#          Iterations 9
# Entered : Para24 	AIC : 243.49802433802614
# Optimization terminated successfully.
#          Current function value: 0.132125
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133957
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134061
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133665
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134021
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134033
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.133008
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134078
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132757
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.134088
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134097
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134058
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.134048
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132609
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133939
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.134095
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134024
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133920
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.134056
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133933
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133068
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.133984
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133354
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134032
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132733
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.130780
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.133888
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133487
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134097
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133847
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.131482
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132659
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134094
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133846
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133491
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.131772
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134095
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132902
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134086
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133785
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133904
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133773
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133625
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.131862
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.133459
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133015
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133839
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134096
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133874
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132913
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133248
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134085
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134083
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133831
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133900
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133815
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133897
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132897
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132617
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.132473
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132938
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.131450
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.133463
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133620
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.129135
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.133862
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.134048
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.131284
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.133543
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132079
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129135
#          Iterations 12
# Entered : Para66 	AIC : 236.63444213387027
# Optimization terminated successfully.
#          Current function value: 0.127060
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128702
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129087
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128731
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129100
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128962
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128014
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129131
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129115
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.129134
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129134
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128272
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129119
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.127209
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128429
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129134
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129119
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128530
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129095
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128884
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128173
#          Iterations 15
# Optimization terminated successfully.
#          Current function value: 0.129019
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128400
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129018
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.127571
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.127682
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.128960
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128662
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129129
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129032
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125908
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.127773
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129128
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128779
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128633
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.126675
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129131
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128883
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129118
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128905
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129046
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128765
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128740
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128356
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128570
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.127827
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128622
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129117
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129047
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128534
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128278
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129122
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129135
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128635
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128933
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128979
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128959
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128084
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129135
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.127481
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128027
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129038
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.128293
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128340
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128887
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129074
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.128827
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.128661
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.129009
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125908
#          Iterations 12
# Entered : Para32 	AIC : 232.87174118388413
# Optimization terminated successfully.
#          Current function value: 0.124231
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125351
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125855
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125331
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125907
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125835
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.124574
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125908
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125907
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125908
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125900
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.124969
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125894
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.123967
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.124789
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125908
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125891
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125135
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125807
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125555
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.124843
#          Iterations 15
# Optimization terminated successfully.
#          Current function value: 0.125871
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125351
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125867
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.124344
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.124293
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125674
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125456
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125908
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125613
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.124767
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125883
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125572
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125523
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.123673
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125905
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125643
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125899
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125727
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125802
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125518
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125546
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125096
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125273
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.124558
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125446
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125900
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125829
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125224
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125085
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125859
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125908
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125291
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125653
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125724
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125704
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.124597
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125878
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.124206
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.124974
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125895
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.124762
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.124937
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125640
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125882
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125708
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.125438
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.125838
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123673
#          Iterations 13
# Entered : Para37 	AIC : 230.8797286651265
# Optimization terminated successfully.
#          Current function value: 0.122305
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123183
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123621
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122725
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123670
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123599
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122526
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123653
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123671
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123649
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123663
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122569
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.123671
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.121779
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122588
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.123666
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123651
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122839
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.123514
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123437
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122810
#          Iterations 15
# Optimization terminated successfully.
#          Current function value: 0.123610
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122942
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.123650
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122158
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.121791
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123397
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123174
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123669
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123377
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122241
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123661
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123368
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123363
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123645
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123272
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123664
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123526
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123467
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123328
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123261
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122909
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123094
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122173
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123173
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123645
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123644
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122956
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122898
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123628
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123670
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123036
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123388
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123310
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123508
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122446
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123598
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122059
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123033
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123653
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122256
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.122376
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123404
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123662
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123542
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123191
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.123499
#          Iterations 14
# Break : Significance Level
# Optimization terminated successfully.
#          Current function value: 0.123673
#          Iterations 13
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  893
# Model:                          Logit   Df Residuals:                      888
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 09 Nov 2021   Pseudo R-squ.:                  0.2679
# Time:                        11:48:11   Log-Likelihood:                -110.44
# converged:                       True   LL-Null:                       -150.86
# Covariance Type:            nonrobust   LLR p-value:                 1.153e-16
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   -545.6343    202.672     -2.692      0.007    -942.864    -148.405
# Para24        -0.0026      0.001     -2.660      0.008      -0.005      -0.001
# Para66        23.0447      8.684      2.654      0.008       6.024      40.065
# Para32         0.0212      0.009      2.262      0.024       0.003       0.040
# Para37         0.0641      0.033      1.966      0.049       0.000       0.128
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.21 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# AIC: 230.8797286651265
# BIC: 254.852661569509
# Final Variables: ['intercept', 'Para24', 'Para66', 'Para32', 'Para37']

# %% [markdown]
# ####  sklearn 패키지의 RFE 함수 (비추천)

# %%
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
# REF를 사용하기 위해서는 표준화를 반드시 먼저 수행 (단점1)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)
X_std = pd.DataFrame(X_std)
X_std.columns = xvar

# %%
model = LogisticRegression(solver="liblinear")
rfe = RFE(model, n_features_to_select=4) # X변수를 몇 개를 선택해야하는지 미리 지정해야함 (단점2)
rfe.fit(X_std, y)

print("Num Features: ",rfe.n_features_) 
print("Selected Features: ",xvar[rfe.support_])
# Out:
# Num Features:  4
# Selected Features:  Index(['Para09', 'Para12', 'Para24', 'Para66'], dtype='object')

# %% [markdown]
# #### Genetic 알고리즘

# %%
import genetic_algorithm as genetic

# %%
# X, Y의 이름 정의 
target = 'Defect'
df['Defect']=np.where(df['Defect']=="NG", 1, 0)

# %%
# Execute Genetic Algorithm to obtain Important Feature
np.random.seed(0)
#feature_set, acc_score = genetic.ga(df, xvar, target, 10, 1000)
feature_set, acc_score = genetic.ga(df, xvar, target, 10, 100)

# %%
# Print List of Features
print('Optimal Feature Set\n',X.columns[feature_set==1],'\nAIC =', round(1/acc_score))

# %% [markdown]
# ### Embedding 방법을 이용한 feature selection

# %% [markdown]
# #### Decision Tree 방법

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
clf.fit(X, y)
clf.feature_importances_

# %%
X.columns[clf.feature_importances_>0.001]
