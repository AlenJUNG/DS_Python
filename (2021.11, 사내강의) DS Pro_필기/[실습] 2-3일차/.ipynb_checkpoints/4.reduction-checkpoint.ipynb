# %% [markdown]
# # Dimension Reduction 예제

# %% [markdown]
# ## 신용카드를 소지한 고객 데이터: 17개 변수로 구성
# 예: 구매액, 현금서비스, 사용한도금액, 최소결제금액, 완납비율, 보유기간 등

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("creditcard.csv")
df = df.drop('CUST_ID',axis=1)

# %% [markdown]
# #### 결측치 확인 및 처리

# %%
df = df.fillna(df.median())
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### 우측 치우침이 심한 변수가 많음
# #### 로그 변환을 수행 (0에는 로그를 취할 수 없으므로, 1을 더한 후 로그변환)

# %%
xvar = df.columns
df1 = df.copy()
xvarlog = ['BALANCE', 'PURCHASES','ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',     
       'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS','MINIMUM_PAYMENTS']
df1[xvarlog] = np.log(1+df1[xvarlog])

# %% [markdown]
# ## 차원축소
# #### 상관관계 강한 변수들 확인하여 차원축소 필요성 점검

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df1.corr(),cmap='coolwarm',annot=True)
plt.show()

# %% [markdown]
# #### 주성분 분석, Scree Plot

# %%
from sklearn.preprocessing import StandardScaler # 주성분 분석 전 항상 표준화를 해야함
from sklearn.decomposition import PCA
scaler = StandardScaler()
df1_std = scaler.fit_transform(df1) # 표준화된 데이터
df1_std = pd.DataFrame(df1_std)
df1_std.columns = xvar

# %%
pca = PCA() # <----- PCA 실행
pca.fit(df1_std) 
pca.explained_variance_  # eigenvalues
# Out:
# array([5.7597428 , 3.73427418, 1.59448727, 1.25629506, 1.11624494,
#        0.84968913, 0.70886247, 0.53456637, 0.43629492, 0.31182109,
#        0.21595463, 0.14836816, 0.11751005, 0.09639532, 0.04752194,
#        0.04452457, 0.02934675])

# %%
plt.plot(pca.explained_variance_, 'o-')
plt.show()

# %%
np.cumsum(pca.explained_variance_) / len(xvar)# eigenvalue 누적 비율
# Out:
# array([0.3388084 , 0.55847159, 0.65226496, 0.72616467, 0.79182613,
#        0.84180785, 0.88350564, 0.91495072, 0.94061513, 0.95895754,
#        0.97166076, 0.9803883 , 0.98730065, 0.99297096, 0.99576637,
#        0.99838547, 1.00011174])

# %% [markdown]
# #### 주성분 2개 추출

# %%
pca2 = PCA(n_components=2) # 무조건 2차원으로 줄이겠다
pca2.fit(df1_std) 
pca2.explained_variance_  # eigenvalues
# Out:
# array([5.7597428 , 3.73427418])

# %%
pca2.components_  # eigenvectors : 계수
# Out:
# array([[-0.1185047 ,  0.0223868 ,  0.36449546,  0.20988669,  0.32755772,
#         -0.2961129 ,  0.36759007,  0.22063689,  0.31364343, -0.24823707,
#         -0.27705021,  0.37723001,  0.04935136,  0.0568715 , -0.09882433,
#          0.17764258,  0.06099107],
#        [ 0.43693695,  0.33043499,  0.12004231,  0.21558572,  0.07264932,
#          0.25560709,  0.11753841,  0.21505394,  0.07119847,  0.27306049,
#          0.28424598,  0.16616792,  0.24969921,  0.31625094,  0.36760798,
#         -0.12045269,  0.09103534]])

# %%
df1_pc2 = pca2.fit_transform(df1_std) 
df1_pc2 = pd.DataFrame(df1_pc2) 
df1_pc2.columns = ['PC1', 'PC2'] 
df1_pc2
# Out:
#            PC1       PC2
# 0    -0.308736 -2.677785
# 1    -3.424275  1.058570
# 2     1.547443  1.317364
# 3    -1.276786 -1.167951
# 4    -1.170484 -1.326857
# ...        ...       ...
# 8945  1.707985 -2.792515
# 8946  1.272427 -2.122396
# 8947  0.971040 -3.218050
# 8948 -2.764786 -3.854598
# 8949 -0.108285 -0.705255
#
# [8950 rows x 2 columns]

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=df1_pc2, x="PC1", y="PC2", alpha = 0.05)
plt.show()

# %%
sns.displot(data=df1_pc2, x="PC1", y="PC2", kind="kde")
plt.show()

# %% [markdown]
# #### t-SNE 방법

# %%
from sklearn.manifold import TSNE
np.random.seed(0)
tsne = TSNE(n_components=2, perplexity=30) # 2차원으로 설정, perlexity 는 이웃의 범위
df1_tsne2 = tsne.fit_transform(df1_std) # 2차원으로 변수 변환

# %%
df1_tsne2 = pd.DataFrame(df1_tsne2) 
df1_tsne2.columns = ['tsne1', 'tsne2'] 
df1_tsne2
# Out:
#           tsne1      tsne2
# 0      5.653912 -49.853790
# 1     58.682598  18.316462
# 2    -25.586912  17.951010
# 3     22.222639  -7.932053
# 4      1.723266  23.221609
# ...         ...        ...
# 8945  13.388829 -30.060406
# 8946   8.637612 -29.808155
# 8947  10.933016 -29.274654
# 8948  22.571157  16.546406
# 8949 -10.988628  40.643158
#
# [8950 rows x 2 columns]

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=df1_tsne2, x="tsne1", y="tsne2", alpha = 0.05)
plt.show()

# %%
sns.displot(data=df1_tsne2, x="tsne1", y="tsne2", kind="kde")
plt.show()
