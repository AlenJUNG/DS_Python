# %% [markdown]
# # Feature Engineering 예제

# %% [markdown]
# ## 신용카드를 소지한 고객 데이터: 17개 변수로 구성
# 예: 구매액, 현금서비스, 사용한도금액, 최소결제금액, 완납비율, 보유기간 등

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns # seaborn : 그래프 그리는 패키지
sns.__version__  # '!pip install seaborn -- upgrade' 수행
# Out:
# '0.11.1'

# %%
df = pd.read_csv("creditcard.csv")
df # print(df)와 같음
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.info() # pandas는 2가지 포맷이 있음 df. ~~, pd. ~~
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.drop('CUST_ID', axis=1, inplace=True)
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %% [markdown]
# ## Feature transformation

# %% [markdown]
# #### 결측치 확인 및 처리

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
plt.subplots(figsize=(15,10))
sns.boxplot(data=df, width= 0.5, fliersize=2)
plt.show()

# %%
df = df.fillna(df.median())

# %% [markdown]
# #### 데이터 탐색

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
xvar=df.columns
plt.figure(figsize=(25,30))
for i in range(0,17):
    plt.subplot(6,3,i+1)
    sns.kdeplot(data=df, x=xvar[i]) # KDE : Kernel Density Estimation (커널 밀도 추정)
plt.show()

# %% [markdown]
# #### 우측 치우침이 심한 변수가 많음
# #### 로그 변환을 수행 (0에는 로그를 취할 수 없으므로, 1을 더한 후 로그변환)

# %%
df1 = df.copy()
xvarlog = ['BALANCE', 'PURCHASES','ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',     
       'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS','MINIMUM_PAYMENTS']
df1[xvarlog] = np.log(1+df1[xvarlog]) # 8개의 변수 중 0인 데이터가 있기 때문에 +1을 해준다, log는 pd 패키지가 아니라 np 패키지임에 주의

# %%
df1.describe()
# Out:
#            BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# count  8950.000000        8950.000000  8950.000000       8950.000000
# mean      6.161637           0.877271     4.899647          3.204274
# std       2.013303           0.236904     2.916872          3.246365
# min       0.000000           0.000000     0.000000          0.000000
# 25%       4.861995           0.888889     3.704627          0.000000
# 50%       6.773521           1.000000     5.892417          3.663562
# 75%       7.628099           1.000000     7.013133          6.360274
# max       9.854515           1.000000    10.800403         10.615512
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean                 3.352403      3.319086             0.490351
# std                  3.082973      3.566298             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
plt.figure(figsize=(25,35))
for i in range(0,17):
    plt.subplot(6,3,i+1)
    sns.kdeplot(data=df1, x=xvar[i])
plt.show()

# %%
plt.subplots(figsize=(15,10))
sns.boxplot(data=df1, width= 0.5, fliersize=2)
plt.show()

# %% [markdown]
# ## 비지도학습 feature selection
# #### 상관관계 강한 변수들 확인하여 필요하면 제거

# %%
corr = df1.corr() # df1 : 위에서 이미 로그변환을 했었음
corr[corr > 0.85] # 조건에 맞는 애들만 출력, 비지도학습 feature selection의 기준
# Out:
#                                   BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                               1.0                NaN        NaN
# BALANCE_FREQUENCY                     NaN                1.0        NaN
# PURCHASES                             NaN                NaN   1.000000
# ONEOFF_PURCHASES                      NaN                NaN        NaN
# INSTALLMENTS_PURCHASES                NaN                NaN        NaN
# CASH_ADVANCE                          NaN                NaN        NaN
# PURCHASES_FREQUENCY                   NaN                NaN        NaN
# ONEOFF_PURCHASES_FREQUENCY            NaN                NaN        NaN
# PURCHASES_INSTALLMENTS_FREQUENCY      NaN                NaN        NaN
# CASH_ADVANCE_FREQUENCY                NaN                NaN        NaN
# CASH_ADVANCE_TRX                      NaN                NaN        NaN
# PURCHASES_TRX                         NaN                NaN   0.888988
# ...

# %%
xvar_drop = ['PURCHASES','PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_TRX','PURCHASES_FREQUENCY']
df2 = df1.drop(xvar_drop, axis=1)
xvar2 = df2.columns

# %% [markdown]
# #### df2 는 최종 데이터, xvar2는 최종 변수명

# %%
corr = df2.corr() # feature selection 한 데이터
corr[corr > 0.85]
# Out:
#                             BALANCE  BALANCE_FREQUENCY  ONEOFF_PURCHASES  \
# BALANCE                         1.0                NaN               NaN
# BALANCE_FREQUENCY               NaN                1.0               NaN
# ONEOFF_PURCHASES                NaN                NaN               1.0
# INSTALLMENTS_PURCHASES          NaN                NaN               NaN
# CASH_ADVANCE                    NaN                NaN               NaN
# ONEOFF_PURCHASES_FREQUENCY      NaN                NaN               NaN
# CASH_ADVANCE_FREQUENCY          NaN                NaN               NaN
# PURCHASES_TRX                   NaN                NaN               NaN
# CREDIT_LIMIT                    NaN                NaN               NaN
# PAYMENTS                        NaN                NaN               NaN
# MINIMUM_PAYMENTS                NaN                NaN               NaN
# PRC_FULL_PAYMENT                NaN                NaN               NaN
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df2.corr(),cmap='coolwarm',annot=True) # 히트맵 그림, cor 숫자에 따라 그래픽 작업
plt.show()
